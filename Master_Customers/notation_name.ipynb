# %%
import pandas as pd
path=r'C:\Users\SSN0609\Stanley Black & Decker\Latin America - Regional Marketing - Marketing Analytics\Data\Processed-Dataflow\Master_Customers\Master_Customers.xlsx'
df=pd.read_excel(path, sheet_name='customers', engine='openpyxl')

# %%
import pandas as pd
import numpy as np
import re
import networkx as nx
# 1. CORRECCIÓN DE IMPORTACIÓN: Usar el módulo distance.JaroWinkler
from rapidfuzz.distance import JaroWinkler as jaro_winkler 

# --- 1. Preprocesamiento (sin cambios) ---
def clean_text_strict(text):
    if pd.isna(text): 
        return ""
    text = str(text).lower()
    text = re.sub(r'[^\w\s]', '', text) 
    return re.sub(r'\s+', ' ', text).strip()


# --- 2. Función de Jaro-Winkler Optimizada (con llamada corregida) ---

def jaro_winkler_clustering(unique_names, threshold=95, batch_size=2000):
    N = len(unique_names)
    matches = []
    clean_names = [clean_text_strict(name) for name in unique_names]

    for i in range(0, N, batch_size):
        end = min(i + batch_size, N)
        
        for j in range(i, N): 
            name_j = clean_names[j]
            
            for k in range(i, end): 
                
                if k >= j: 
                    continue
                
                name_k = clean_names[k]
                
                # 2. CORRECCIÓN DE LLAMADA: Usar jaro_winkler.similarity()
                sim = jaro_winkler.normalized_similarity(name_k, name_j) 
                
                # JaroWinkler.normalized_similarity retorna un valor entre 0 y 1. 
                # Multiplicamos por 100 para usar el threshold en escala 0-100.
                if (sim * 100) >= threshold:
                    matches.append((k, j))
        
        print(f"Procesado batch {i} a {end}. Matches encontrados: {len(matches)}")
        
    return matches

# --- 3. Función Principal de Estandarización (sin cambios funcionales) ---

def standardize_names_jarowinkler(df, col_name='Sold-To Customer Name', similarity_threshold=95):
    
    print("1. Obteniendo nombres únicos...")
    unique_names = df[col_name].dropna().unique()
    
    if not 90 <= similarity_threshold <= 100:
        raise ValueError("El umbral Jaro-Winkler debe estar entre 90 y 100.")

    print(f"2. Calculando similitudes Jaro-Winkler por lotes (Umbral: {similarity_threshold})...")
    
    matched_pairs = jaro_winkler_clustering(
        unique_names, 
        threshold=similarity_threshold,
        batch_size=1000 
    )
    
    print(f"3. Construyendo grafo con {len(matched_pairs)} conexiones...")
    G = nx.Graph()
    G.add_nodes_from(range(len(unique_names)))
    G.add_edges_from(matched_pairs)
    
    canonical_map = {}
    print("4. Resolviendo clusters y seleccionando nombres canónicos...")
    
    for component in nx.connected_components(G):
        if len(component) > 1:
            names_in_group = [unique_names[i] for i in component]
            representative = max(names_in_group, key=len)
            
            for idx in component:
                canonical_map[unique_names[idx]] = representative
    
    print("5. Mapeando al dataframe original...")
    
    df['Canonical Name'] = df[col_name].map(canonical_map)
    df['Canonical Name'] = df['Canonical Name'].fillna(df[col_name])
    
    return df

# %%
df_result = standardize_names_jarowinkler(df, 
                                          col_name='Sold-To Customer Name', 
                                          similarity_threshold=97)
# Out:
# 1. Obteniendo nombres únicos...
# 2. Calculando similitudes Jaro-Winkler por lotes (Umbral: 97)...
# Procesado batch 0 a 1000. Matches encontrados: 221
# Procesado batch 1000 a 2000. Matches encontrados: 361
# Procesado batch 2000 a 3000. Matches encontrados: 517
# Procesado batch 3000 a 4000. Matches encontrados: 702
# Procesado batch 4000 a 5000. Matches encontrados: 869
# Procesado batch 5000 a 6000. Matches encontrados: 1093
# Procesado batch 6000 a 7000. Matches encontrados: 1205
# Procesado batch 7000 a 8000. Matches encontrados: 1334
# Procesado batch 8000 a 9000. Matches encontrados: 1470
# Procesado batch 9000 a 10000. Matches encontrados: 1595
# Procesado batch 10000 a 11000. Matches encontrados: 1725
# Procesado batch 11000 a 12000. Matches encontrados: 1865
# Procesado batch 12000 a 13000. Matches encontrados: 2034
# Procesado batch 13000 a 14000. Matches encontrados: 2174
# Procesado batch 14000 a 15000. Matches encontrados: 2347
# Procesado batch 15000 a 16000. Matches encontrados: 2495
# Procesado batch 16000 a 17000. Matches encontrados: 2615
# Procesado batch 17000 a 18000. Matches encontrados: 2753
# Procesado batch 18000 a 19000. Matches encontrados: 2886
# Procesado batch 19000 a 20000. Matches encontrados: 3006
# Procesado batch 20000 a 21000. Matches encontrados: 3153
# Procesado batch 21000 a 22000. Matches encontrados: 3239
# Procesado batch 22000 a 23000. Matches encontrados: 3328
# Procesado batch 23000 a 24000. Matches encontrados: 3404
# Procesado batch 24000 a 25000. Matches encontrados: 3496
# Procesado batch 25000 a 26000. Matches encontrados: 3575
# Procesado batch 26000 a 27000. Matches encontrados: 3624
# Procesado batch 27000 a 28000. Matches encontrados: 3758
# Procesado batch 28000 a 29000. Matches encontrados: 3832
# Procesado batch 29000 a 30000. Matches encontrados: 3884
# Procesado batch 30000 a 31000. Matches encontrados: 3965
# Procesado batch 31000 a 32000. Matches encontrados: 4013
# Procesado batch 32000 a 33000. Matches encontrados: 4036
# Procesado batch 33000 a 34000. Matches encontrados: 4054
# Procesado batch 34000 a 35000. Matches encontrados: 4099
# Procesado batch 35000 a 36000. Matches encontrados: 4141
# Procesado batch 36000 a 37000. Matches encontrados: 4201
# Procesado batch 37000 a 38000. Matches encontrados: 4257
# Procesado batch 38000 a 39000. Matches encontrados: 4324
# Procesado batch 39000 a 40000. Matches encontrados: 4443
# Procesado batch 40000 a 41000. Matches encontrados: 4503
# Procesado batch 41000 a 42000. Matches encontrados: 4563
# Procesado batch 42000 a 43000. Matches encontrados: 4649
# Procesado batch 43000 a 44000. Matches encontrados: 4725
# Procesado batch 44000 a 45000. Matches encontrados: 4778
# Procesado batch 45000 a 46000. Matches encontrados: 4830
# Procesado batch 46000 a 47000. Matches encontrados: 4886
# Procesado batch 47000 a 48000. Matches encontrados: 4937
# Procesado batch 48000 a 49000. Matches encontrados: 4994
# Procesado batch 49000 a 50000. Matches encontrados: 5064
# Procesado batch 50000 a 51000. Matches encontrados: 5102
# Procesado batch 51000 a 52000. Matches encontrados: 5149
# Procesado batch 52000 a 53000. Matches encontrados: 5210
# Procesado batch 53000 a 54000. Matches encontrados: 5261
# Procesado batch 54000 a 55000. Matches encontrados: 5310
# Procesado batch 55000 a 56000. Matches encontrados: 5345
# Procesado batch 56000 a 57000. Matches encontrados: 5403
# Procesado batch 57000 a 58000. Matches encontrados: 5444
# Procesado batch 58000 a 59000. Matches encontrados: 5525
# Procesado batch 59000 a 60000. Matches encontrados: 5603
# Procesado batch 60000 a 61000. Matches encontrados: 5678
# Procesado batch 61000 a 62000. Matches encontrados: 5753
# Procesado batch 62000 a 63000. Matches encontrados: 5837
# Procesado batch 63000 a 64000. Matches encontrados: 5865
# Procesado batch 64000 a 65000. Matches encontrados: 5883
# Procesado batch 65000 a 66000. Matches encontrados: 5912
# Procesado batch 66000 a 67000. Matches encontrados: 5952
# Procesado batch 67000 a 68000. Matches encontrados: 5970
# Procesado batch 68000 a 69000. Matches encontrados: 5992
# Procesado batch 69000 a 70000. Matches encontrados: 6001
# Procesado batch 70000 a 71000. Matches encontrados: 6013
# Procesado batch 71000 a 72000. Matches encontrados: 6022
# Procesado batch 72000 a 73000. Matches encontrados: 6031
# Procesado batch 73000 a 74000. Matches encontrados: 6044
# Procesado batch 74000 a 75000. Matches encontrados: 6061
# Procesado batch 75000 a 76000. Matches encontrados: 6212
# Procesado batch 76000 a 77000. Matches encontrados: 6428
# Procesado batch 77000 a 78000. Matches encontrados: 6438
# Procesado batch 78000 a 79000. Matches encontrados: 6439
# Procesado batch 79000 a 79408. Matches encontrados: 6439
# 3. Construyendo grafo con 6439 conexiones...
# 4. Resolviendo clusters y seleccionando nombres canónicos...
# 5. Mapeando al dataframe original...

# %%
df.to_csv(r'C:\Users\SSN0609\Stanley Black & Decker\Latin America - Regional Marketing - Marketing Analytics\Data\Processed-Dataflow\Master_Customers\Master_Customers_name.csv', index=False, encoding='utf-8-sig')
